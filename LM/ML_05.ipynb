# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes_data = pd.read_csv('diabetes.csv')

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    Pedigree  Age  Outcome
# 0     0.627   50        1
# 1     0.351   31        0
# 2     0.672   32        1
# 3     0.167   21        0
# 4     2.288   33        1

# %%
# prompt: implementation of K-Nearest Neighbors algorithm and analyze and
# find its steps.

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# Split the data into features (X) and target (y)
X = diabetes_data.drop('Outcome', axis=1)
y = diabetes_data['Outcome']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Training the K-NN model on the training set
classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
classifier.fit(X_train, y_train)

# Predicting the test set results
y_pred = classifier.predict(X_test)

# Making the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Calculating the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)


# Steps of the K-Nearest Neighbors algorithm:
# 1. Calculate the distance between the new data point and all the training data points.
# 2. Select the k-nearest neighbors based on the calculated distances.
# 3. Assign the new data point to the class that is most frequent among its k-nearest neighbors.


# Analyzing the results:
# The confusion matrix shows the number of true positives, true negatives, false positives, and false negatives.
# The accuracy score represents the overall performance of the model.
# We can further analyze the model by looking at other performance metrics such as precision, recall, and F1-score.
# Out:
# Confusion Matrix:
# [[114  16]
#  [ 22  40]]
# Accuracy: 0.8020833333333334

# %%
# prompt: Compute
# confusion matrix, accuracy, error rate, precision and recall on the given dataset.

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# ... (Your existing code) ...

# Making the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Calculating the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculating the error rate
error_rate = 1 - accuracy
print("Error Rate:", error_rate)

# Calculating precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculating recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)
# Out:
# Confusion Matrix:
# [[114  16]
#  [ 22  40]]
# Accuracy: 0.8020833333333334
# Error Rate: 0.19791666666666663
# Precision: 0.7142857142857143
# Recall: 0.6451612903225806
